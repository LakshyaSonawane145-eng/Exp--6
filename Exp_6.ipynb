# %%
# Lakshya Sonawane PRN:25070123068
# Title : Study of conditional statement in Python

# %%
#1.Check whether a number is postitive , negative or zero
num = int(input("Enter a number:"))
if num >0:
 print("Positive")
elif num==0:
  print("Zero")
else:
  print("Negative number")
# Out:
# Enter a number:-4
# Negative number

# %%
#2. Check wheter a number is even or odd

num = int(input("Enter a number:"))
if num % 2 ==0:
  print("Even")
else:
  print("Odd")
# Out:
# Enter a number:2
# Even

# %%
#3. Find the largest of three numbers
a = int(input("Enter a number:"))
b = int(input("Enter a number:"))
c = int(input("Enter a number:"))

if a>=b and a>=c:
    print(a,"is the largest number")
elif b>=a and b>=c:
  print(b,"is the largest number")
else :
  print(c,"is the largest number")
# Out:
# Enter a number:5
# Enter a number:2
# Enter a number:9
# 9 is the largest number

# %%
#4. Get input from user for one subject and
#Calculate grade using if-elif-else

grade = float(input("Enter your marks:"))
if grade >= 90:
  print("Grade A")
elif grade >= 75:
  print("Grade B")
elif grade >= 60:
  print("Grade C")
elif grade >= 40:
  print("Grade D")
elif grade < 40:
  print("fail")
# Out:
# Enter your marks:92
# Grade A

# %%
#5. To find the given year is a leap year or not
year = int(input("Enter a year:"))
if (year %4 == 0 and year%100!=0) or year%400 == 0:
  print(year,"is a leap year")
else:
  print(year,"is not a leap year")
# Out:
# Enter a year:2000
# 2000 is a leap year

# %%
#6. Write a python program to make increement in the date
# Input date from user
day = int(input("Enter day: "))
month = int(input("Enter month: "))
year = int(input("Enter year: "))

# Number of days in each month
days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

# Check leap year
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    days[1] = 29   # February has 29 days in leap year

# Increase day by 1
day = day + 1

# Check if day exceeds days in month
if day > days[month - 1]:
    day = 1
    month = month + 1

    # Check if month exceeds December
    if month > 12:
        month = 1
        year = year + 1

# Print next date
print("Next Date:", day, "-", month, "-", year)
# Out:
# Enter day: 5
# Enter month: 5
# Enter year: 2000
# Next Date: 6 - 5 - 2000

# %%
#7. Write a python program to calculate the gross salary of an employee
# if basic <=10000:HRA
# Otherwise:HRA = 30% , DA = 95%***

basic = float(input("Enter basic salary:"))
if basic <= 10000:
  hra = basic * 0.20
  da = basic * 0.00
elif basic <= 20000:
  hra =  basic * 0.25
  da = basic * 0.90
else :
  hra = basic *0.30
  da = basic *0.95

gross = basic + hra + da
print("Gross Salary:" , gross)
# Out:
# Enter basic salary:25000
# Gross Salary: 56250.0

# %%
#8 . Write a Python program to calculate income tax based on annual income

# Up to ₹2,50,000 : No tax

# ₹2,50,000 - ₹5,00,000 :5%

# ₹5,00,001 - ₹10,00,000 :20%

# Above ₹10,00,000 :30%

income = float(input("Enter your annual income (₹): "))
tax = 0

if income <= 250000:
    tax = 0

elif income <= 500000:
    tax = (income - 250000) * 0.05

elif income <= 1000000:
    tax = (250000 * 0.05) + (income - 500000) * 0.20

else:
    tax = (250000 * 0.05) + (500000 * 0.20) + (income - 1000000) * 0.30

print("Income Tax to be paid: ₹", tax)
# Out:
# Enter your annual income (₹): 1200000
# Income Tax to be paid: ₹ 172500.0

# %%
#9. Wtite a python program to check if a given character is a consonant or a vowel
character = str(input("Enter your character:"))

if character in 'aeiouAEIOU':
  print("Vowel")
else:
  print("Consonant")
# Out:
# Enter your character:c
# Consonant

# %%
#10. Write a python program to make increement in the date
date = input("Enter date in dd/mm/yyyy format: ")

dd, mm, yy = map(int, date.split("/"))


if mm in (1, 3, 5, 7, 8, 10, 12):
    max1 = 31
elif mm in (4, 6, 9, 11):
    max1 = 30
elif mm == 2:
    if (yy % 4 == 0 and yy % 100 != 0) or (yy % 400 == 0):
        max1 = 29
    else:
        max1 = 28
else:
    print("Date is invalid")
    exit()

if dd < 1 or dd > max1:
    print("Date is invalid")

elif dd == max1 and mm != 12:
    dd = 1
    mm += 1
    print("Next date is:", f"{dd:02d}/{mm:02d}/{yy}")

elif dd == 31 and mm == 12:
    dd = 1
    mm = 1
    yy += 1
    print("Next date is:", f"{dd:02d}/{mm:02d}/{yy}")

else:
    dd += 1
    print("Next date is:", f"{dd:02d}/{mm:02d}/{yy}")
# Out:
# Enter date in dd/mm/yyyy format: 05/08/2007
# Next date is: 06/08/2007
